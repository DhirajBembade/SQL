# %% [markdown]
# <a href="https://colab.research.google.com/github/DhirajBembade/SQL/blob/main/SQL%20Practice-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# ![4.png](data:image/png;base64,...)
